# %% [markdown]
# ### Задание №1
# Массив A состоит из целых положительных чисел длин отрезков. Составьте из трех отрезков такой треугольник, чтобы его периметр был максимально возможным. Если невозможно составить треугольник с положительной площадью функция возвращает 0.

# %%
arr = [6,4,9,8,34]
arr = sorted(arr)

def triangle(arr):
    arr = sorted(arr)
    max = 0
    for i in range(len(arr)-2):
        if arr[i+2]<arr[i]+arr[i+1]:
            if arr[i+2]+arr[i+1]+arr[i]>max:
                max = arr[i+2]+arr[i+1]+arr[i]
    if max==0:
        return 0
    else:
        return max
    
print(triangle(arr))
# Out:
# 23

# %% [markdown]
# ### Задание №2
# Дан массив неотрицательных целых чисел nums. Расположите их в таком порядке, чтобы вместе они образовали максимально возможное число. Замечание: Результат может быть очень большим числом, поэтому представьте его как string, а не integer.

# %%
def maxValue(arr):
    arr = sorted(arr)
    answer = ''
    for i in range(len(arr)-1,-1,-1):
        answer+=str(arr[i])
    return answer

arr = [7,2,6,4]
maxValue(arr)
# Out:
# '7642'

# %% [markdown]
# ### Задание №3
# Дана матрица mat размером m * n, значения целочисленные. Напишите функцию, сортирующую каждую диагональ матрицы по возрастанию и возвращающую получившуюся матрицу.

# %%
def f(m = 50, n = 50, min_limit = -250, max_limit = 1026):
    from random import randint
    a = [[randint(min_limit, max_limit) for j in range(n)] for i in range(m)]
    return a

m=4
n=4
a = f(m,n,1,9)
for i in range(m):
    for j in range(n):
        print(a[i][j],end=' ')
    print("")
print(" ")

def sortDiagonal(a,m,n):
    sortMas=[]
        
    for i in range(m):
        ic = i
        for j in range(n):
            if 0<=j<n and 0<=i<m:
                sortMas.append(a[i][j])
            i+=1
        
        sortMas = sorted(sortMas)
    
        for j in range(n):
            if 0<=j<n and 0<=ic<m:
                a[ic][j] = sortMas[j]
            ic+=1
        sortMas = []

    sortMas = []

    for j in range(1,n):
        jc = j
        for i in range(m):
            if 0<=j<n and 0<=i<m:
                sortMas.append(a[i][j])
            j+=1
    
        sortMas = sorted(sortMas)
    
        for i in range(m):
            if 0<=jc<n and 0<=i<m:
                a[i][jc] = sortMas[i]
            jc+=1
        sortMas = []

sortDiagonal(a,m,n)
for i in range(m):
    for j in range(n):
        print(a[i][j],end=' ')
    print("")
# Out:
# 2 2 3 9
# 2 5 1 9
# 3 1 3 9
# 9 2 1 1
#
# 1 1 3 9
# 1 2 2 9
# 2 1 3 9
# 9 3 2 5
